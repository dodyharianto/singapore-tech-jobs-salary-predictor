# %%
import serpapi
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY')
client = serpapi.Client(api_key=SERPAPI_API_KEY)

# %%
try:
    results = client.search({
        'engine': 'google_jobs',
        'q': 'data scientist',
        'location': 'Singapore',
        'google_domain': 'google.com.sg',
        'hl': 'en',
        'gl': 'sg',
        'start': 2
    })
except serpapi.HTTPError as e:
    if e.status_code == 401:
        print(e.error)
    elif e.status_code == 400:
        pass
    elif e.status_code == 429:
        pass
except serpapi.TimeoutError as e:
    print(f'The request timed out: {e}')

# %%
results
# Out:
# {
#     "search_metadata": {
#         "id": "69e24980d10c6a85604096f4",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/anLBi_DxptaXlgrcv2Yo4g/69e24980d10c6a85604096f4.json",
#         "created_at": "2026-04-17 14:53:52 UTC",
#         "processed_at": "2026-04-17 14:53:52 UTC",
#         "google_jobs_url": "https://www.google.com.sg/search?q=data+scientist&uule=w+CAIQICIJU2luZ2Fwb3Jl&hl=en&gl=sg&udm=8",
#         "raw_html_file": "https://serpapi.com/searches/anLBi_DxptaXlgrcv2Yo4g/69e24980d10c6a85604096f4.html",
#         "total_time_taken": 0.79
#     },
#     "search_parameters": {
#         "q": "data scientist",
#         "engine": "google_jobs",
#         "location_requested": "Singapore",
#         "location_used": "Singapore",
#         "google_domain": "google.com.sg",
#         "hl": "en",
#         "gl": "sg"
#     },
#     "filters": [
#         {
#             "name": "Date posted",
#             "options": [
#                 {
#                     "name": "Yesterday",
#                     "parameters": {
#                         "uds": "ALYpb_ncDc7jTlmw6Mmq7NjuX5c-7XlnUbmzhC_KCtba2Cc2Zl8I9cpCtLYFi-y1BT1zl6wdI2WNPBwwoXJQ7nHWkdEqcHAXWR9OR2QTb41vOk3aexjdcJIDCnThCQA64iPpqR-AYJbTp0kyyCTqmWSUF8xG1yrrEOoJXoq6_AaqsOsXyG5hmlqnlYew_yDXob3jsqtqQy8_kP2p2D6S4O9wjhxeRZZYR2hbQoPVhJdpNVHXPB5viGYvJOVJMxqJXQ7s1wjt9cRuEkXm_BkDa_7sHzwIGzI5yyboqwl5-SeR022yZQP9yyC5hmAEOxBJNnploiLukKOeoS9RlacHOZkaA9gBFCyuKInxeAdDQs0vn_jxzgIBJcs",
#                         "q": "data scientist since yesterday"
#                     },
#                     "link": "https://www.google.com.sg/search?sca_esv=cc650c0e994125fa&hl=en&gl=sg&q=data+scientist+since+yesterday&uds=ALYpb_ncDc7jTlmw6Mmq7NjuX5c-7XlnUbmzhC_KCtba2Cc2Zl8I9cpCtLYFi-y1BT1zl6wdI2WNPBwwoXJQ7nHWkdEqcHAXWR9OR2QTb41vOk3aexjdcJIDCnThCQA64iPpqR-AYJbTp0kyyCTqmWSUF8xG1yrrEOoJXoq6_AaqsOsXyG5hmlqnlYew_yDXob3jsqtqQy8_kP2p2D6S4O9wjhxeRZZYR2hbQoPVhJdpNVHXPB5viGYvJOVJMxqJXQ7s1wjt9cRuEkXm_BkDa_7sHzwIGzI5yyboqwl5-SeR022yZQP9yyC5hmAEOxBJNnploiLukKOeoS9RlacHOZkaA9gBFCyuKInxeAdDQs0vn_jxzgIBJcs&udm=8&sa=X&ved=2ahUKEwi6nt3wkfWTAxVqF2IAHS3vO7IQkbEKegQIFxAC",
#                     "serpapi_link": "https://serpapi.com/search.json?engine=google_jobs&gl=sg&google_domain=google.com.sg&hl=en&location=Singapore&q=data+scientist+since+yesterday&uds=ALYpb_ncDc7jTlmw6Mmq7NjuX5c
"https://serpapi.com/search.json?engine=google_jobs&gl=sg&google_domain=google.com.sg&hl=en&location=Singapore&q=data+scientist+in+the+last+week&uds=ALYpb_ncDc7jTlmw6Mmq7NjuX5c-l8pFxudptR4VqSltWsYR0AJtf7YlWA8IEFGs5VBgo9VQf8YYkdzrYPZMuD496MiNTmvFmcbpkhghwFRYtfIccYYdBhOr2mf3O8zf5-mpQq3wQ6zcDBHAXu893bIPj_vFSNL7A3q47XRtSS7KBb6yh32A3qinHr0w1_PWCezGWKYREstTjEcqVDZErAXEZjbHnqgqAAs4Et04G7mO5S3lCxIyf7PudI16bs1dX0fgWUEPYb0-Qj1n4exYpeBOsHApGKKAq5WNLxpgml9A01lkYrDSXCfEYQhjOaw4qfvrwjopCo9wBGuaZu7wNxSU2ia-zqeakbfu-I3yh28Y-qWfKwA9xIM"
#                 },
#                 {
#                     "name": "Last month",
#                     "parameters": {
#                         "uds": "ALYpb_ncDc7jTlmw6Mmq7NjuX5c-0wJtUeOLxqPQlvKZWFTRxHuivwWX4VEVyh-sxlACTCXEvuRF6zC9syZUX-gzipcitKJFQjoYojB0KQnrdbq6SdMelbkNN06EBlNc1tpQh8TfYmFAxbLnqqNkeJGJ6gDlAkF71KcNSZGSkzdU5tEeImww9iF9fTLFxAmNXx49_nGbjjFhwXhTMhkmOlaBF3Td1fxS1gCGkO0-VVMPWdV2AXEoWZyF5W9PXxfc5l1t_ZKjj5UpHBCNTsOxTTIDBKwfo2KJjD1c384-IiuK8ZihgS-JPmexAdz9KlhNahzBl4kwkSmSCAmWNtFwNWvyNM-dSs05JaTj7zIhOB7AMK2CsiNFrvM",
#                         "q": "data scientist in the last month"
#                     },
# ...
#             "thumbnail": "https://serpapi.com/searches/69e24980d10c6a85604096f4/images/Jq9gudNjnhhObFwjRomVQL2wlmUSzPLVroA5XYuqp3c.jpeg",
#             "extensions": [
#                 "1 day ago",
#                 "Full\u2013time"
#             ],
#             "detected_extensions": {
#                 "posted_at": "1 day ago",
#                 "schedule_type": "Full\u2013time"
#             },
#             "source_link": "https://www.efinancialcareers.sg/jobs-Singapore-Singapore-VPAVP_Data_Scientist_Group_Audit.id24130442",
#             "job_title": "VP/AVP, Data Scientist, Group Audit | Singapore, SG",
#             "description": "Responsibilities  \r\n\u2022 Collaborate closely with business auditors to understand their analytics requirements, and work with our LOBT to design data analytics solutions to address those needs, including rule based analytics, traditional AI/ML and GenAI/Agentic \r\n\u2022 Support the full lifecycle activities, including requirement gathering, development, deployment and post-deployment monitoring. \r\n\u2022 Collaborate with team members and cross-functional/location teams to drive analytics and tools adoption \r\n\u2022 Participate in building and maintaining effective working relationships with stakeholders, communicate analytical insights clearly to both technical and non-technical audiences, fostering understanding and adoption \r\n\u2022 Ensure adherence to internal policies/standards and regulatory requirements.  Requirement  \r\n\u2022 Master/Bachelor in Computer Science, Business Analytics or other related disciplines \r\n\u2022 At least 7 years of experience in managing and delivering data analytics projects \r\n\u2022 Experience in developing AI/ML and/or GenAI solutions \r\n\u2022 Experience with data engineering using Python / SQL / Spark / Pandas \r\n\u2022 Experience with Tableau for dashboard development \r\n\u2022 Knowledge of banking industry and internal audit function is a plus \r\n\u2022 Demonstrated eagerness to learn and adapt to new technologies and methodologies. \r\n\u2022 Good communication and presentation skills \r\n\u2022 A team player  Location: \r\nDBS Asia Central \r\n \r\n Job:  \r\nAnalytics \r\n \r\n Schedule:  \r\nRegular \r\n \r\n Employee Status:",
#             "apply_options": [
#                 {
#                     "title": "EFinancialCareers SG",
#                     "link": "https://www.efinancialcareers.sg/jobs-Singapore-Singapore-VPAVP_Data_Scientist_Group_Audit.id24130442?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 }
#             ],
#             "job_id": "..."
#         },
#         {
#             "title": "Assistant Data Scientists",
#             "company_name": "OAKTREE CONSULTING",
#             "location": "Singapore",
#             "via": "MyCareersFuture",
#             "share_link": "https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=LaoKUXyOnQzONRzdAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCQBBAUWxzBBuntshKwEaroCGIEsHEOkyWYbMSd5bMFCk9g97QkxibX3x4yXuRZLmIF8WgcERFqK2noPMR-L4-8OAOhHC0PXCAktkNtNz3qlF2xogMqZuxeptafhoO1PFkZiT_tNLjSHFApTbbbqY0BrdeXfNzcysKOFyr-n5pTlUJPkDtg8PII_0AT5Sz7pUAAAA&shmds=v1_ATWGeeOFDfGyV7OUysKnKOIDI-PyIN-x5rkJg6mcijn-hBjEUg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=LaoKUXyOnQzONRzdAAAAAA%3D%3D",
#             "thumbnail": "https://serpapi.com/searches/69e24980d10c6a85604096f4/images/7XTL78g5kUWn81_K1hAuWYJmBic3cHJ3da8VF0ScAvg.jpeg",
#             "extensions": [
#                 "4 days ago",
#                 "$6K\u2013$10K a month",
#                 "Full\u2013time"
#             ],
#             "detected_extensions": {
#                 "posted_at": "4 days ago",
#                 "salary": "$6K\u2013$10K a month",
#                 "schedule_type": "Full\u2013time"
#             },
#             "source_link": "https://www.mycareersfuture.gov.sg/job/assistant-data-scientists-oaktree-consulting-40fbc5afc27ac418fbdad3876139bf64",
#             "job_title": "Assistant Data Scientists",
#             "description": "The Data Scientist works closely with business stakeholders to uncover challenges, refine use cases, and design analytical solutions that drive measurable outcomes. This role spans the entire data science lifecycle\u2014problem framing, data preparation, modelling, evaluation, communication of insights, and enabling adoption through compellingvisualizations and decision\u2011support tools.\n\nKey Responsibilities\n\n1. Problem Definition & StakeholderEngagement\n\nFacilitate discussions with business users to understand their     pain points, clarify objectives, and convert them into analytically sound     data science problem statements.Collaborate with stakeholders throughout the project to refine     hypotheses, validate findings, and align on priorities.Manage expectations and timelines while balancing analytical     depth with business needs.2. Data Preparation & FeatureEngineering\n\nConduct data cleaning, preprocessing, and transformation for     both structured and unstructured data to ensure high data quality.Perform feature engineering to extract meaningful attributes     that enhance model performance.Identify relevant datasets and integrate multiple data sources     to support analytical work.3. Analytical Modelling &Experimentation\n\nExplore data using statistical techniques to uncover trends,     patterns, and relationships.Build machine learning models for prediction, classification,     clustering, or other analytical tasks as required by the use case.Evaluate model performance and iterate based on stakeholder feedback     and performance metrics.4. Insights Delivery & Communication\n\nTranslate analytical results into actionable recommendations     that stakeholders can apply to drive decisions or business improvements.Develop clear, compelling narratives that explain insights and     model behaviours in an accessible manner.Present analysis with well\u2011designed visuals, dashboards, and     interactive tools that support storytelling and data exploration.5. Visualisation & User\u2011Facing Tools\n\nDesign dashboards and interactive visualizations to facilitate     self\u2011service analytics and real\u2011time data monitoring.Apply strong visualization principles to ensure insights are     intuitive and impactful.Build and deploy customised visual interfaces tightly     integrated with underlying data systems.6. Deployment, Monitoring &Continuous Improvement\n\nSupport model deployment into production environments and     collaborate with engineering teams to operationalize models.Monitor model performance over time and recommend enhancements     as required.Contribute to agile project workstreams and participate in     ceremonies such as stand\u2011ups, reviews, and retrospectives.Required Skills & Competencies\n\nAnalytical & Technical Skills\n\nAbility to convert business challenges into analytical     questions and identify appropriate data sources.Proficiency in writing data preparation and analysis scripts     using tools such as Python, R, SQL, pandas, or equivalent.Strong foundation in descriptive statistics, probability, data     exploration, and hypothesis testing.Skilled in building and validating machine learning models,     using modern techniques and frameworks.Solid understanding of system design concepts, data structures,     and algorithms.Data Visualization & Storytelling\n\nStrong command of data visualization principles and tools.Capable of developing dashboards and interactive visual tools     (e.g., using Tableau, Power BI, Plotly, or custom frameworks).Ability to communicate analytical insights through structured     storytelling tailored for decision\u2011makers.Data Engineering Familiarity\n\nUnderstanding of data modelling, data access patterns, and data     storage structures such as data lakes, data marts, and data warehouses.Familiarity with REST APIs, web protocols, and data extraction     via web scraping technologies.Comfortable working with big d ...
#             "apply_options": [
#                 {
#                     "title": "MyCareersFuture",
#                     "link": "https://www.mycareersfuture.gov.sg/job/assistant-data-scientists-oaktree-consulting-40fbc5afc27ac418fbdad3876139bf64?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Foundit",
#                     "link": "https://www.foundit.sg/job/assistant-data-scientists-oaktree-consulting-singapore-50061428?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Talent.com",
#                     "link": "https://sg.talent.com/view?id=614926124080242351&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "JobLeads",
#                     "link": "https://www.jobleads.com/sg/job/data-assistant-6-month-contract-sgd-2600-sgd-3100-jo-28390--singapore--e55a67dd807e70ff2d8023420a79aff01?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Jobrapido.com",
#                     "link": "https://sg.jobrapido.com/jobpreview/8104560069443584000?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Recruit.net",
#                     "link": "https://www.recruit.net/job/assistant-data-scientists-jobs/4B33364D16788A91?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 }
#             ],
#             "job_id": "..."
#         },
#         {
#             "title": "GoTo Financial - Senior Data Scientist",
#             "company_name": "Confidential",
#             "location": "Singapore",
#             "via": "BeBee",
#             "share_link": "https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=iGpvhWCDmBfOhWKEAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXNMQ7CMAxAUbH2BjB5RqJBSCwwMIDoAcpeuSGkRsGOYg8duQMT1-MktMvfvl71XVSnRm4CV2JkT5hgA21gkgIXNITWU2AjNfi9P_CUHjRg8QMIQyMSU1gdB7OsB-dUUx3V0MjXXl5OOPQyumnSOZ0OWEJOaKHb7bdjnTmul2fhB91nY7KJoSWOmKWEP6pjYbmcAAAA&shmds=v1_ATWGeePz0u3Aqoe67YnDqB0icGiutQljDgJ8eGvkz7pXKJ0-xQ&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=iGpvhWCDmBfOhWKEAAAAAA%3D%3D",
#             "extensions": [
#                 "3 days ago",
#                 "Full\u2013time"
#             ],
#             "detected_extensions": {
#                 "posted_at": "3 days ago",
#                 "schedule_type": "Full\u2013time"
#             },
#             "source_link": "https://bebee.com/sg/jobs/goto-financial-senior-data-scientist-confidential-singapore--clickajo-045d21ba0d80d0a64da5910241b30f80",
#             "job_title": "GoTo Financial - Senior Data Scientist",
#             "description": "FinTech - Data Products & Infra \u2022 Singapore  About the Role  As a Data Scientist specializing in deep learning at GoTo, you will tackle complex challenges in computer vision, voice, and text processing. You will lead the development and deployment of advanced AI models that directly impact our key business products. Your responsibilities will include enhancing our systems with cutting\u2011edge deep learning models and ensuring they are scalable in a production environment. This role offers the opportunity to drive innovation, solve critical business challenges, and shape the future of AI\u2011driven financial solutions at GoTo.\nAbout the Team  At GoTo, our Data Science team is at the forefront of developing cutting\u2011edge deep learning solutions. We build advanced computer vision models for our KYC system, which is the leading KYC solution in Indonesia and is now expanding to external customers. We also create sophisticated deep\u2011learning models for computer vision, voice and text processing. Our team is composed of members with diverse backgrounds, bringing expertise in mathematics, statistics, machine learning, and deep learning. We tackle some of the most challenging business problems at GoPay and are passionate about both the technical aspects of data science and the tangible impact our models have on the business.\nWhat You Will Do   Work with data like images, videos, audio, and text etc.  Design, train, optimize, and deploy deep learning models with GPU.  Develop comprehensive unit tests and documentation, and rigorously evaluate and benchmark model performance and quality.  Communicate effectively between the business team and the engineering team to gather and implement project requirements.  Own the end\u2011to\u2011end process, from defining the technical problem to deploying the solution in collaboration with engineers.  Stay current with the latest advancements in deep learning and AI technologies.   What You Will Need   5+ years of experience in deep learning, particularly with computer vision, voice, and text processing.  Proficient in data preprocessing, model training, evaluation, and optimisation.  Practical experience in applying deep learning to solve real business problems, with models successfully deployed and used in production environments.  Proficient with deep learning frameworks such as PyTorch, and familiar with Python, C++, and inference engines like NCNN.   Experience with cloud platforms like GCP or AWS, and working knowledge of Android/iOS is a plus.  Strong communication skills to understand business needs and effectively convey analytical solutions.  Ability to write clear and concise technical documentation.  A Master\u2019s or PhD in Computer Science, Data Science, AI, or a related field.   About GoTo Group  GoTo is the largest digital ecosystem in Indonesia. GoTo's mission is to 'empower progress' by offering technology infrastructure and solutions that help everyone to access and thrive in the digital economy.\nThe GoTo ecosystem provides a wide range of services, including mobility, delivery, payments, financial services, and technology solutions for merchants. The ecosystem also provides e-commerce services through Tokopedia and banking services through its partnership with",
#             "apply_options": [
#                 {
#                     "title": "BeBee",
#                     "link": "https://bebee.com/sg/jobs/goto-financial-senior-data-scientist-confidential-singapore--clickajo-045d21ba0d80d0a64da5910241b30f80?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Jobrapido.com",
#                     "link": "https://sg.jobrapido.com/jobpreview/7154055137932083200?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "Recruit.net",
#                     "link": "https://www.recruit.net/job/goto-financial-data-scientist-jobs/48E761BDCF335C2A?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 },
#                 {
#                     "title": "WhatJobs",
#                     "link": "https://en-sg.whatjobs.com/jobs/goto-financial-senior-data/singapore?id=85196985&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#                 }
#             ],
#             "job_id": "..."
#         }
#     ],
#     "serpapi_pagination": {
#         "next_page_token": "...",
#         "next": "https://serpapi.com/search.json?engine=google_jobs&gl=sg&google_domain=google.com.sg&hl=en&location=Singapore&next_page_token=...%3D%3D&q=data+scientist"
#     }
# }

# %%
jobs_df = pd.DataFrame(results['jobs_results'])
jobs_df
# Out:
#                                                title  \
# 0                    Data Scientist Analyst (Python)
# 1  Associate, Data Scientist, Group Legal, Compli...
# 2  Senior/Data Scientist, Process Modelling & Sim...
# 3  Associate, Data Scientist, Group Legal, Compli...
# 4           Data Scientist (GEN AI with AWS Bedrock)
# 5     Data Scientist – Applied AI & Machine Learning
# 6  Senior Data Scientist — Generative AI & Risk Lead
# 7  VP/AVP, Data Scientist, Group Audit | Singapor...
# 8                          Assistant Data Scientists
# 9             GoTo Financial - Senior Data Scientist
#
#                                     company_name   location  \
# 0                                        Exasoft  Singapore
# 1                               DBS Bank Limited  Singapore
# 2  Home Team Science and Technology Agency (HTX)  Singapore
# 3                               DBS Bank Limited  Singapore
# 4                       INCOME INSURANCE LIMITED  Singapore
# 5                                            UBS  Singapore
# 6                                   Confidential  Singapore
# 7                               DBS Bank Limited  Singapore
# 8                             OAKTREE CONSULTING  Singapore
# 9                                   Confidential  Singapore
#
#                     via                                         share_link  \
# 0    LinkedIn Singapore  https://www.google.com.sg/search?ibp=htl;jobs&...
# 1             Jobstreet  https://www.google.com.sg/search?ibp=htl;jobs&...
# 2           Careers@Gov  https://www.google.com.sg/search?ibp=htl;jobs&...
# 3  EFinancialCareers SG  https://www.google.com.sg/search?ibp=htl;jobs&...
# 4       MyCareersFuture  https://www.google.com.sg/search?ibp=htl;jobs&...
# 5                 BeBee  https://www.google.com.sg/search?ibp=htl;jobs&...
# 6                 BeBee  https://www.google.com.sg/search?ibp=htl;jobs&...
# 7  EFinancialCareers SG  https://www.google.com.sg/search?ibp=htl;jobs&...
# 8       MyCareersFuture  https://www.google.com.sg/search?ibp=htl;jobs&...
# 9                 BeBee  https://www.google.com.sg/search?ibp=htl;jobs&...
#
#                                            thumbnail  \
# 0  https://serpapi.com/searches/69e24980d10c6a856...
# 1                                                NaN
# 2  https://serpapi.com/searches/69e24980d10c6a856...
# 3  https://serpapi.com/searches/69e24980d10c6a856...
# 4                                                NaN
# 5  https://serpapi.com/searches/69e24980d10c6a856...
# 6                                                NaN
# 7  https://serpapi.com/searches/69e24980d10c6a856...
# 8  https://serpapi.com/searches/69e24980d10c6a856...
# 9                                                NaN
#
#                                   extensions  \
# 0                  [6 hours ago, Contractor]
# 1                     [1 day ago, Full–time]
# 2     [2 days ago, Full–time and Contractor]
# 3                     [1 day ago, Full–time]
# 4  [4 days ago, $7K–$12K a month, Full–time]
# 5                    [3 days ago, Full–time]
# 6                    [3 days ago, Full–time]
# 7                     [1 day ago, Full–time]
# 8  [4 days ago, $6K–$10K a month, Full–time]
# 9                    [3 days ago, Full–time]
#
#                                  detected_extensions  \
# 0  {'posted_at': '6 hours ago', 'schedule_type': ...
# 1  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 2  {'posted_at': '2 days ago', 'schedule_type': '...
# 3  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 4  {'posted_at': '4 days ago', 'salary': '$7K–$12...
# 5  {'posted_at': '3 days ago', 'schedule_type': '...
# 6  {'posted_at': '3 days ago', 'schedule_type': '...
# 7  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 8  {'posted_at': '4 days ago', 'salary': '$6K–$10...
# 9  {'posted_at': '3 days ago', 'schedule_type': '...
#
#                                          source_link  \
# 0  https://sg.linkedin.com/jobs/view/data-scienti...
# 1              https://sg.jobstreet.com/job/91567896
# 2  https://jobs.careers.gov.sg/jobs/hrp/17430455/...
# 3  https://www.efinancialcareers.sg/jobs-Singapor...
# 4  https://www.mycareersfuture.gov.sg/job/data-sc...
# 5  https://bebee.com/sg/jobs/data-scientist-appli...
# 6  https://bebee.com/sg/jobs/senior-data-scientis...
# 7  https://www.efinancialcareers.sg/jobs-Singapor...
# 8  https://www.mycareersfuture.gov.sg/job/assista...
# 9  https://bebee.com/sg/jobs/goto-financial-senio...
#
#                                            job_title  \
# 0                    Data Scientist Analyst (Python)
# 1  Associate, Data Scientist, Group Legal, Compli...
# 2  Senior/Data Scientist, Process Modelling & Sim...
# 3  Associate, Data Scientist, Group Legal, Compli...
# 4           Data Scientist (GEN AI with AWS Bedrock)
# 5     Data Scientist – Applied AI & Machine Learning
# 6  Senior Data Scientist — Generative AI & Risk Lead
# 7  VP/AVP, Data Scientist, Group Audit | Singapor...
# 8                          Assistant Data Scientists
# 9             GoTo Financial - Senior Data Scientist
#
#                                          description  \
# 0  Responsibilities\n\n\n\n\n•Collaborate with cr...
# 1  Business Function Group Legal, Compliance & Se...
# 2  What the role is:\n\nWe are looking for someon...
# 3  Business Function \r\n \r\nGroup Legal, Compli...
# 4  Analytics Center of Excellence (COE) at Income...
# 5  Your role\nAre you interested in helping to de...
# 6  A global consulting firm based in Singapore is...
# 7  Responsibilities  \r\n• Collaborate closely wi...
# 8  The Data Scientist works closely with business...
# 9  FinTech - Data Products & Infra • Singapore  A...
#
#                                        apply_options  \
# 0  [{'title': 'LinkedIn Singapore', 'link': 'http...
# 1  [{'title': 'Jobstreet', 'link': 'https://sg.jo...
# 2  [{'title': 'Careers@Gov', 'link': 'https://job...
# 3  [{'title': 'EFinancialCareers SG', 'link': 'ht...
# 4  [{'title': 'MyCareersFuture', 'link': 'https:/...
# 5  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 6  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 7  [{'title': 'EFinancialCareers SG', 'link': 'ht...
# 8  [{'title': 'MyCareersFuture', 'link': 'https:/...
# 9  [{'title': 'BeBee', 'link': 'https://bebee.com...
#
#                                               job_id
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCBBbmFseX...
# 1  eyJqb2JfdGl0bGUiOiJBc3NvY2lhdGUsIERhdGEgU2NpZW...
# 2  eyJqb2JfdGl0bGUiOiJTZW5pb3IvRGF0YSBTY2llbnRpc3...
# 3  eyJqb2JfdGl0bGUiOiJBc3NvY2lhdGUsIERhdGEgU2NpZW...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCAoR0VOIE...
# 5  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCDigJMgQX...
# 6  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBTY2llbnRpc3...
# 7  eyJqb2JfdGl0bGUiOiJWUC9BVlAsIERhdGEgU2NpZW50aX...
# 8  eyJqb2JfdGl0bGUiOiJBc3Npc3RhbnQgRGF0YSBTY2llbn...
# 9  eyJqb2JfdGl0bGUiOiJHb1RvIEZpbmFuY2lhbCAtIFNlbm...

# %%
jobs = results['jobs_results']
for job in jobs:
    print(job)
# Out:
# {'title': 'Data Scientist Analyst (Python)', 'company_name': 'Exasoft', 'location': 'Singapore', 'via': 'LinkedIn Singapore', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=n1LQbn67YXtpiTUNAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCQBBAUWxTW1lNqRZZEQTRSlBshRwgTJZxd2WdWTJTJJ0XsPKGnsTY_Ff96j2r9mc0hMYnYktqcGLM4-TyNloUXsH39YGHdKCEvY8gDFeRkGlxjGZFD86p5jqooSVfe3k6YepkcNOk_7QasaeS0ajd7jZDXTis55cBVe4GiaFJHLBITz-UtQH7kAAAAA&shmds=v1_ATWGeeNwTxH5n4d9iGopEdBdzxrPyHWbO_IURhmadnGK4CZsLA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=n1LQbn67YXtpiTUNAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['6 hours ago', 'Contractor'], 'detected_extensions': {'posted_at': '6 hours ago', 'schedule_type': 'Contractor'}, 'source_link': 'https://sg.linkedin.com/jobs/view/data-scientist-analyst-python-at-exasoft-4402370631', 'job_title': 'Data Scientist Analyst (Python)', 'description': 'Responsibilities\n\n\n\n\n•Collaborate with cross-functional teams to gather business requirements\n\n•Perform feature engineering using customer, product, digital, and behavioural data\n\n•Design and build scalable AI models\n\n•Evaluate AI model performance using technical and business metrics\n\n•Design end-to-end model pipeline and conduct various tests to ensure robustness of solution\n\n•Prepare model documentations and testing reports\n\n\n\n\nRequirements\n\n\n\n\n•Bachelor’s or Master’s degree in Data Science, Computer Science, Statistics, or related fields.\n\n•3–5 years of experience in a data science or analytics role.\n\n•Strong command of Python (especially for text analytics and data manipulation).\n\n•Solid experience with SQL for querying large datasets.\n\n•Familiar with machine learning libraries and GenAI.\n\n•Ability to work with various types of data and derive meaningful insights.\n\n•Strong communication skills and stakeholder management experience.', 'apply_options': [{'title': 'LinkedIn Singapore', 'link': 'https://sg.linkedin.com/jobs/view/data-scientist-analyst-python-at-exasoft-4402370631?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}], 'job_id': '...'}
# {'title': 'Associate, Data Scientist, Group Legal, Compliance & Secretariat', 'company_name': 'DBS Bank Limited', 'location': 'Singapore', 'via': 'Jobstreet', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=LCAJRPwLuKGWWu-yAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXOMQrCQBBAUWw9giBMZSEhEcFGK6NgY5fKKkzWYTO62Vl2RrD0Dh7G-3gSY_O7B3_6mUwve1VxjEYFHNEQGscUjdUKOGV5JDiTx1DAQYYUGKMjWEBDLpNhHh18X2-4SQdKmF0PEuEk4gPNdr1Z0m1VqYbSq6GxK50MlUTq5FmNSP9ptcdMKYwP7XqzepYp-uX8WDdQY7zDmQc2ugJHaDh6TJLpB33oftm6AAAA&shmds=v1_ATWGeeMj2Wlj0ge8yPE8qPeOPJwTIEmyTjz4pXH0yv2AUfw7zg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=LCAJRPwLuKGWWu-yAAAAAA%3D%3D', 'extensions': ['1 day ago', 'Full–time'], 'detected_extensions': {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://sg.jobstreet.com/job/91567896', 'job_title': 'Associate, Data Scientist, Group Legal, Compliance & Secretariat', 'description': "Business Function Group Legal, Compliance & Secretariat ensures that the bank's interests are protected by zealously guarding and enhancing its reputation and capital. We also work to maintain good standing with all our regulators, customers, and business partners. Because we believe that at the heart of business banking is to uphold the values of trust and integrity for all our stakeholders. \n\n\nJob Purpose \n\n\nReporting to the AI and ML lead, the data scientist will be responsible for various data science and machine learning initiatives and projects in Group LCS. This role will work closely with senior management, business users and technology partners to co-develop and execute the strategy and roadmap of applying AI/ML to improve the effectiveness and efficiency of the Bank's business processes and controls. \n\n\nResponsibilities \n\n\n Own and execute machine learning products and initiatives regionally for Group LCS. Conceptualise, plan, develop, and deliver relevant analytics models and innovative solutions in Financial Crime, Legal and Compliance, such as Anti-Money Laundering Detection, Transaction Monitoring, Fraud Prevention, Money Mule detection, and Sanctions Screening. Partner with domain experts and data scientists from cross-functional teams to drive projects. Condense analysis into actionable insights for informed decision-making, strategy development and formulation of standards to enhance business performance and operations at LCS. Ensure adherence to the bank's governance policy and best practices in AI/ML industrialisation, including but not limited to code review, creation and adoption of reusable assets, active adoption of bank's AI protocol, data governance, post-deployment monitoring, and regular technical / audit / business review of the solution.  Requirements  Degree with a strong focus in machine learning, data mining, or statistical / mathematical modelling with deep theoretical knowledge. 2+ years of relevant working experience with hands-on development of data analytics or AI/ML solutions. Familiar with analytics and machine learning platforms and how it integrates with upstream and downstream data and production systems. Hands-on experience in end-to-end data science projects covering problem formulation, exploratory data analysis, ML modelling, production deployment, monitoring and production support. Familiar with developing machine learning pipelines following dev practice such as versioning, branching, merging, linting, testing and writing codes in a structured and modularized way. Good presentation and communication skills. Able to explain technical concepts and solutions to a non-technical audience. Technical skills: Python, SQL, libraries and tools for AI/ML, data visualisation.  Location: \nDBS Asia Central Job:  \nAnalytics \n\n\nSchedule:  \nRegular \n\n\nEmployee Status:  \nFull time\ninformation_technology", 'apply_options': [{'title': 'Jobstreet', 'link': 'https://sg.jobstreet.com/job/915 ...
# {'title': 'Senior/Data Scientist, Process Modelling & Simulation, Decision Science, xData', 'company_name': 'Home Team Science and Technology Agency (HTX)', 'location': 'Singapore', 'via': 'Careers@Gov', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=SxfqQmpDin9C4_uGAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_zVOOwrCQBDF1iNYTSUqISuCTawEQRtBiIVd2GyGzcpmJ-ysEDvv4A09iaNi83g83m_8Go1ticFRVDudNJTGYUiOUwanSAaZ4UgNeu-ChSmUrrt5nRyFDHZoHAv7ZQxmMHwrXo8nXKkGRh1NC2LYE1mPk02bUs-FUsw-t5ykx-SGOkUBaxqUhPgDFbc6Yi87WK3WyyHvg10UB-oQzqi7_x7o0Ihg2kCe7B22VtQ7zA7nyxyc3JLLuqeIbz9X-DblAAAA&shmds=v1_ATWGeePgQ1bmYbDjZONWYxibkVSsyZnmJRwsPpqSQb8F9LVcUw&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=SxfqQmpDin9C4_uGAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/nvNsO5pDd5T62blPOgazAvO8cMoGADOFok8cOqZaWX4.png', 'extensions': ['2 days ago', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://jobs.careers.gov.sg/jobs/hrp/17430455/005056a3-53e2-1fd1-8e95-042a9c76d3ec', 'job_title': 'Senior/Data Scientist, Process Modelling & Simulation, Decision Science, xData', 'description': 'What the role is:\n\nWe are looking for someone who is creative, curious, collaborative and enjoys challenges. If you like to design, build and develop cutting-edge simulation models that can be applied in advance applications like Digital Twins with AI for Home Team operations, we want you! \nThe successful candidate’s primary job role would be with the Process Modelling and Simulation team in Decision Science. There are also opportunities for job holder to gain exposure to related work in other teams within HTX. We believe in upskilling our officers and exposing them to work spanning end-to-end development of simulation projects.\nWhat you will be working on:\n\n•\tWork in a Data Science team with other stakeholders to identify, scope, develop and implement Data Science and AI solutions to address users’ needs.\n•\tConduct applied research in advance simulation and data science techniques to tailor models to Home Team operational use cases. These techniques include but are not limited to:\no\tAgent-based simulation\no\tDiscrete-event simulation\no\tTraffic simulation\no\tCrowd simulation\no\tPhysics based simulation\no\tAI based simulation approaches\no\tData mining and knowledge discovery\no\tStatistical forecasting methods\n•\tExamples of use cases include but are not limited to:\no\tProcess models for immigration clearance processes\no\tCrowd models for event planning\no\tTraffic models for car/motorcycle/heavy vehicle clearance analysis\no\tCrowd models for disaster / adverse event planning\no\tDynamic behavior models for human modelling  \n•\tBuild Digital Twin applications using industry-standard 3D engines such as Unity, Unreal and NVIDIA Omniverse\n•\tPrepare and present analytical insights that effectively describe complex quantitative methods in clear and concise communications to business users and stakeholders.\n•\tSupport large-scale and complex projects which may be developed in-house or co-developed with external or consultancy agencies and/or academic institutions\nWhat we are looking for:\n\n•\tCandidates should possess at least a bachelor’s degree in a quantitative discipline: Engineering, Mathematics, Statistics, Data Science, Operations Research or related disciplines. \n•\tCandidates must be good problem solvers with strong analytical and mathematical skills. Background in data science or operations research, particularly knowledge in modelling and simulation, is required. Candidates preferably have at least 2 years of relevant working experience, with some experience in AI ML/DL/GenAI. \n•\tExperience or interest in modelling and simulation with tools such as AnyLogic, PTV Vissim, ExtendSim and other simulation platforms.\n•\tExper ...
# {'title': 'Associate, Data Scientist, Group Legal, Compliance & Secretariat | Singapore, SG', 'company_name': 'DBS Bank Limited', 'location': 'Singapore', 'via': 'EFinancialCareers SG', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=qah0fGmda2zdDWlaAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_0WOO04DQRAFReojIFl6EQFa7VpIJBD5I23ibA5gtYfWbMPs9Gi6LTkg4A4cinv4JCwRSWVV761-7layNdMo5NzhQE4IUbi4mHcYm14qjpwod9jrXLNQiYwHBI6Nndri4RNBSqKqbUmEEbevb7zrGcbU4gQtGFVT5vvXyb3ayzCY5T6Zk0vso86DFj7rdVgk-8PJJmpc8_Lp9PS8ufa1pMf1YRewo_KBo8zi_AYp_8O_cVvC9coAAAA&shmds=v1_ATWGeeM5IMdHuMoGnFK8rKVC-jPEXhifF6wZALipINP3J1TPUg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=qah0fGmda2zdDWlaAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/JvDPtZKGmgNAOJgjsNe8RcqLkGiu2XYgnKf72UTx0UE.jpeg', 'extensions': ['1 day ago', 'Full–time'], 'detected_extensions': {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://www.efinancialcareers.sg/jobs-Singapore-Singapore-Associate_Data_Scientist_Group_Legal_Compliance__Secretariat.id24130391', 'job_title': 'Associate, Data Scientist, Group Legal, Compliance & Secretariat | Singapore, SG', 'description': "Business Function \r\n \r\nGroup Legal, Compliance & Secretariat ensures that the bank's interests are protected by zealously guarding and enhancing its reputation and capital. We also work to maintain good standing with all our regulators, customers, and business partners. Because we believe that at the heart of business banking is to uphold the values of trust and integrity for all our stakeholders. \r\n \r\n Job Purpose \r\n \r\nReporting to the AI and ML lead, the data scientist will be responsible for various data science and machine learning initiatives and projects in Group LCS. This role will work closely with senior management, business users and technology partners to co-develop and execute the strategy and roadmap of applying AI/ML to improve the effectiveness and efficiency of the Bank's business processes and controls. \r\n \r\n Responsibilities  \r\n• Own and execute machine learning products and initiatives regionally for Group LCS. \r\n• Conceptualise, plan, develop, and deliver relevant analytics models and innovative solutions in Financial Crime, Legal and Compliance, such as Anti-Money Laundering Detection, Transaction Monitoring, Fraud Prevention, Money Mule detection, and Sanctions Screening. \r\n• Partner with domain experts and data scientists from cross-functional teams to drive projects. \r\n• Condense analysis into actionable insights for informed decision-making, strategy development and formulation of standards to enhance business performance and operations at LCS. \r\n• Ensure adherence to the bank's governance policy and best practices in AI/ML industrialisation, including but not limited to code review, creation and adoption of reusable assets, active adoption of bank's AI protocol, data governance, post-deployment monitoring, and regular technical / audit / business review of the solution.  Requirements  \r\n• Degree with a strong focus in machine learning, data mining, or statistical / mathematical modelling with deep theoretical knowledge. \r\n• 2+ years of relevant working experience with hands-on development of data analytics or AI/ML solutions. \r\n• Familiar with analytics and machine learning platforms and how it integrates with upstream and downstream data and production systems. \r\n• Hands-on experience in end-to-end data science projects covering problem formulation, exploratory data analysis, ML modelling, production deployment, monitoring and production support. \r\n• Familiar with developing machine learning pipelines following dev practice such as versioning, branching, merging, linting, testing and writing codes in a structured and modularized way. \r\n• Good presentation and communication skills. Able to explain technic ...
# {'title': 'Data Scientist (GEN AI with AWS Bedrock)', 'company_name': 'INCOME INSURANCE LIMITED', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=c5fubI8HuTNVCyRgAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKe_COrQiuCiU21LCdgIVnEsaQxJtOaX5IMdvYOH8F6eRF3e9qL3KEpzQQJqaZUjGwimZcEhZfCwZCA917BVF4_yNoPP8wVXbCEo4aUBdFAi6k6NN4aoD-skCaGLdSBBVsYS7wk61eKQ_FL40wQjvOo7QapZrhZD3Ds9nzCe7asCGK9Ph5RnBexYxY5FDtZBbZ0WPXr1BbbLxoaqAAAA&shmds=v1_ATWGeeMVXXgTlxPj8RijDSPN9MH2ffarX0GK_AC2nLy94DigUg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=c5fubI8HuTNVCyRgAAAAAA%3D%3D', 'extensions': ['4 days ago', '$7K–$12K a month', 'Full–time'], 'detected_extensions': {'posted_at': '4 days ago', 'salary': '$7K–$12K a month', 'schedule_type': 'Full–time'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/data-scientist-income-insurance-67450c47cb20c63238bef4d6b0fd63a4', 'job_title': 'Data Scientist (GEN AI with AWS Bedrock)', 'description': 'Analytics Center of Excellence (COE) at Income Insurance is the enterprise team that champions and develops AI/ML solutions. We focus on in-house solution development as well as partnerships. To ensure the successful execution of Income’s enterprise strategy to build Analytics as a product through impactful AI/ML solutions, driving innovation, and cultivating AI culture, we are seeking a highly skilled and experienced Data Scientist to join our team. The selected candidate will focus on building Generative AI-based solutions\n\n\nResponsibilities:\n\nTake ownership of AI/ML use cases, from design and implementation to continuous enhancement.Act as a technical specialist in AI, primarily focusing on Generative AI. Design and develop solutions to address various business challenges, particularly those related to optimizing operational efficiency.Collaborate with other data engineers, analysts, data scientists, product specialists, and stakeholders to build well-crafted, pragmatic, and robust solutions that meet business requirements.Stakeholder management and engagement: proactively engage with stakeholders to understand their needs and translate them into technical requirements for AI/ML modeling.Maintain documentation of dataset curation, modeling approach, model performance, code changes, and workflows.Demonstrate a strong understanding of data privacy regulations such as PDPA, and AI governance guidelines to ensure compliance.Foster an innovative and growth-oriented mindset, continuously seeking opportunities to enhance AI/ML models and drive improvements across the organization.Requirements:\n\n3–5 years of experience in a data science role, with demonstrable expertise in the AWS platform. Experience with Microsoft Copilot Studio is a plus.Bachelor’s degree in computer science or equivalent.Familiarity with techniques for Document Chunking, Embedding, and Information Retrieval for improving model accuracy and relevance.Expertise in Prompt Engineering for designing and managing effective prompts.Hands-on experience with AWS Bedrock, including deploying solutions using foundation models and integrating them into scalable applications using APIs and orchestration tools.Experience in Agentic Workflow for maximizing the utility of models, including understanding user intent and context to drive meaningful interactions.In-depth knowledge of supervised and unsupervised ML models – linear & logistic regression, clustering, tree-based models like random forest, bagging, and boosting models.Proficient in SQL, Python, and Spark.Proven experience in implementing MLOps practices on AWS.Familiar with Data Warehouses such as Redshift, Hive, and S3.Passionate about technology and always looking to upskill based on new developments in the AI space.AWS or Microsoft certifications will be a plus.Experience in the financial industry, telecommunications, or consulting is prefer ...
# {'title': 'Data Scientist – Applied AI & Machine Learning', 'company_name': 'UBS', 'location': 'Singapore', 'via': 'BeBee', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=64AQwH3JfJPGA8DvAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_x2NMQrCQBBFsU1lbTWVhUVWBButIoIEtArWYbIOm5V1ZslMkdI72Hk8T2K0-cXjPX7xnhX1EQ2h8ZHYohp8ni-ock6RblDVsIQL-j4ywZlw4Mjhb9ylA52A70EYTiIh0WLfm2XdOaeayqCGFn3p5eGEqZPRTZH-ptUeB8oJjdrNdj2WmcNqfj00EBma6QKzDPQFa9j3cZ0AAAA&shmds=v1_ATWGeePQl2q3GMm5SxabCzLCo9liUq7AR6JTfCEeAp2QrIs9zA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=64AQwH3JfJPGA8DvAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/pz06_EmHvrlj62rTD73SD69NOgPveL4vbkZgCXLsBks.png', 'extensions': ['3 days ago', 'Full–time'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://bebee.com/sg/jobs/data-scientist-applied-ai-machine-learning-ubs--theirstack-663111440', 'job_title': 'Data Scientist – Applied AI & Machine Learning', 'description': "Your role\nAre you interested in helping to design, develop, and deliver AI and machine learning solutions within UBS Global Wealth Management?\n\n\nAre you experienced in applying advanced ML and GenAI techniques to real-world business challenges, working closely with product, engineering, and business teams to turn strategic priorities into measurable outcomes? Do you want to contribute to the creation of reusable AI components, experimentation frameworks, and intelligent tools that support clients, advisors, and internal operations globally?\n\n\nWe are looking for a Data Scientist to:\n\n\n\ndevelop, test, and deploy GenAI, agentic, and ML models that address concrete business use cases\nwork with cross-functional partners (product, data, and engineering) to design and integrate scalable AI capabilities into existing systems\nbuild and maintain pipelines for data preparation, experimentation, evaluation, and model monitoring\ncontribute to prompt engineering, retrieval-augmented generation (RAG), and other modern NLP and LLM-based applications\nsupport the development of internal tools and reusable modules (e.g., reasoning agents, evaluation frameworks, feedback loops)\napply best practices in MLOps, model validation, and responsible AI to ensure quality, transparency, and compliance\n\nJob Type\nFull Time\nJob Reference #\n337055BR\nCity\nSingapore\nYour team\nThis is an opportunity to work at the forefront of UBS’s AI transformation—building meaningful, scalable applications that shape the future of wealth management. You’ll be part of a diverse, forward-thinking team where your ideas can directly influence products used across the globe.\nYour expertise\n\nMaster’s or PhD in Computer Science, Machine Learning, Data Science, or related field\nat least 5 years of experience applying ML/AI methods in enterprise or research environments and proven experience with GenAI or NLP applications (LLM fine-tuning, RAG, LangChain, or similar)\nstrong programming skills in Python and experience with ML frameworks (PyTorch, TensorFlow, Scikit-learn, Hugging Face)\nfamiliarity with MLOps tools (CI/CD, model registry, vector databases, containerization)\nability to translate business needs into analytical or ML solutions with tangible impact\nstrong communication and collaboration skills across technical and business teams\nworking knowledge of data privacy, compliance, or governance considerations in regulated industries\nexperience integrating AI models with production systems or APIs is an asset\n\nAbout Us\nUBS is a leading and truly global wealth manager and the leading universal bank in Switzerland. We also provide diversified asset management solutions and focused investment banking capabilities. Headquartered in Zurich, Switzerland, UBS is present in more than 50 markets around the globe.\nWe know that great work is never done alone. Th ...
# {'title': 'Senior Data Scientist — Generative AI & Risk Lead', 'company_name': 'Confidential', 'location': 'Singapore', 'via': 'BeBee', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=giJrLC3Ryri3Jj7EAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xWOMQrCQBAAsc0PtNrKwiIngo1WohCEVOYBYZOsl9Nz97g9JKV_0Df4MF9i0kwzDEz2nWVlRewkwgkTQtU64uQ0we_1gYKYIib3JDicYQkXp3coCbvRvuEmDShhbHsQhkLEelrs-5SC7oxR9bnVNNZt3srDCFMjgxkjnVBrj5GCx0T1Zrse8sB2NT8KX103HaAHx1A5thgk0h8cn4oaqQAAAA&shmds=v1_ATWGeeNWr9ZBa4tReh48DmhUb9_PkeEkz7X_pkFzx9W_pGpEMg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=giJrLC3Ryri3Jj7EAAAAAA%3D%3D', 'extensions': ['3 days ago', 'Full–time'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://bebee.com/sg/jobs/senior-data-scientist-generative-ai-risk-lead-confidential-singapore--clickajo-35173a9bea2a6ac21d26c1d9671bc41a', 'job_title': 'Senior Data Scientist — Generative AI & Risk Lead', 'description': "A global consulting firm based in Singapore is seeking an experienced AI and Data Analytics Leader to drive the development of Generative AI models and oversee project execution. Candidates should hold a Master's or Ph.D. in a Quantitative field and possess over 5 years of relevant experience. Proficiency in Python and expertise in machine learning are essential. This role involves mentoring team members and collaborating with stakeholders to enhance business processes.", 'apply_options': [{'title': 'BeBee', 'link': 'https://bebee.com/sg/jobs/senior-data-scientist-generative-ai-risk-lead-confidential-singapore--clickajo-35173a9bea2a6ac21d26c1d9671bc41a?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}, {'title': 'Trabajo.org', 'link': 'https://sg.trabajo.org/job-979-0b05f42b384a545a51cab409724743a6?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}, {'title': 'WhatJobs', 'link': 'https://en-sg.whatjobs.com/jobs/data-ai-delivery-lead/shenton-way-singapore?id=84971900&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}], 'job_id': '...'}
# {'title': 'VP/AVP, Data Scientist, Group Audit | Singapore, SG', 'company_name': 'DBS Bank Limited', 'location': 'Singapore', 'via': 'EFinancialCareers SG', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=fwdiL-uhjnQDYk7zAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_0XNMQrCMBSAYVx7BEF4s5RGBBedWgpdOhQCXUuahvRpmxeSV-jg4B28hcfyJOrk8m8ff_LaJHXbiLxtUigVK5AajWOMnEIVaPGQLwMy3EGis8pTMCnICt6PJ1yph2hU0COQg4rITmZ7GZl9PAsR45TZyIpRZ5pmQc70tIovir90cVTB-Emx6Y6nw5p5Z_e7spBQKHeDGmdkMwC6__gDJXUsRK0AAAA&shmds=v1_ATWGeeN81UFUOjoaNPy8FIrWyWMX3cAVWlAfh8bVGKUwA_1FfA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=fwdiL-uhjnQDYk7zAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/Jq9gudNjnhhObFwjRomVQL2wlmUSzPLVroA5XYuqp3c.jpeg', 'extensions': ['1 day ago', 'Full–time'], 'detected_extensions': {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://www.efinancialcareers.sg/jobs-Singapore-Singapore-VPAVP_Data_Scientist_Group_Audit.id24130442', 'job_title': 'VP/AVP, Data Scientist, Group Audit | Singapore, SG', 'description': 'Responsibilities  \r\n• Collaborate closely with business auditors to understand their analytics requirements, and work with our LOBT to design data analytics solutions to address those needs, including rule based analytics, traditional AI/ML and GenAI/Agentic \r\n• Support the full lifecycle activities, including requirement gathering, development, deployment and post-deployment monitoring. \r\n• Collaborate with team members and cross-functional/location teams to drive analytics and tools adoption \r\n• Participate in building and maintaining effective working relationships with stakeholders, communicate analytical insights clearly to both technical and non-technical audiences, fostering understanding and adoption \r\n• Ensure adherence to internal policies/standards and regulatory requirements.  Requirement  \r\n• Master/Bachelor in Computer Science, Business Analytics or other related disciplines \r\n• At least 7 years of experience in managing and delivering data analytics projects \r\n• Experience in developing AI/ML and/or GenAI solutions \r\n• Experience with data engineering using Python / SQL / Spark / Pandas \r\n• Experience with Tableau for dashboard development \r\n• Knowledge of banking industry and internal audit function is a plus \r\n• Demonstrated eagerness to learn and adapt to new technologies and methodologies. \r\n• Good communication and presentation skills \r\n• A team player  Location: \r\nDBS Asia Central \r\n \r\n Job:  \r\nAnalytics \r\n \r\n Schedule:  \r\nRegular \r\n \r\n Employee Status:', 'apply_options': [{'title': 'EFinancialCareers SG', 'link': 'https://www.efinancialcareers.sg/jobs-Singapore-Singapore-VPAVP_Data_Scientist_Group_Audit.id24130442?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}], 'job_id': '...'}
# {'title': 'Assistant Data Scientists', 'company_name': 'OAKTREE CONSULTING', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=LaoKUXyOnQzONRzdAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCQBBAUWxzBBuntshKwEaroCGIEsHEOkyWYbMSd5bMFCk9g97QkxibX3x4yXuRZLmIF8WgcERFqK2noPMR-L4-8OAOhHC0PXCAktkNtNz3qlF2xogMqZuxeptafhoO1PFkZiT_tNLjSHFApTbbbqY0BrdeXfNzcysKOFyr-n5pTlUJPkDtg8PII_0AT5Sz7pUAAAA&shmds=v1_ATWGeeOFDfGyV7OUysKnKOIDI-PyIN-x5rkJg6mcijn-hBjEUg&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=LaoKUXyOnQzONRzdAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e24980d10c6a85604096f4/images/7XTL78g5kUWn81_K1hAuWYJmBic3cHJ3da8VF0ScAvg.jpeg', 'extensions': ['4 days ago', '$6K–$10K a month', 'Full–time'], 'detected_extensions': {'posted_at': '4 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/assistant-data-scientists-oaktree-consulting-40fbc5afc27ac418fbdad3876139bf64', 'job_title': 'Assistant Data Scientists', 'description': 'The Data Scientist works closely with business stakeholders to uncover challenges, refine use cases, and design analytical solutions that drive measurable outcomes. This role spans the entire data science lifecycle—problem framing, data preparation, modelling, evaluation, communication of insights, and enabling adoption through compellingvisualizations and decision‑support tools.\n\nKey Responsibilities\n\n1. Problem Definition & StakeholderEngagement\n\nFacilitate discussions with business users to understand their     pain points, clarify objectives, and convert them into analytically sound     data science problem statements.Collaborate with stakeholders throughout the project to refine     hypotheses, validate findings, and align on priorities.Manage expectations and timelines while balancing analytical     depth with business needs.2. Data Preparation & FeatureEngineering\n\nConduct data cleaning, preprocessing, and transformation for     both structured and unstructured data to ensure high data quality.Perform feature engineering to extract meaningful attributes     that enhance model performance.Identify relevant datasets and integrate multiple data sources     to support analytical work.3. Analytical Modelling &Experimentation\n\nExplore data using statistical techniques to uncover trends,     patterns, and relationships.Build machine learning models for prediction, classification,     clustering, or other analytical tasks as required by the use case.Evaluate model performance and iterate based on stakeholder feedback     and performance metrics.4. Insights Delivery & Communication\n\nTranslate analytical results into actionable recommendations     that stakeholders can apply to drive decisions or business improvements.Develop clear, compelling narratives that explain insights and     model behaviours in an accessible manner.Present analysis with well‑designed visuals, dashboards, and     interactive tools that support storytelling and data exploration.5. Visualisation & User‑Facing Tools\n\nDesign dashboards and interactive visualizations to facilitate     self‑service analytics and real‑time data monitoring.Apply strong visualization principles to ensure insights are     intuitive and impactful.Build and deploy customised visual interfaces tightly     integrated with underlying data systems.6. Deployment, Monitoring &Continuous Improvement\n\nSupport model deployment into production environments and     collaborate with engineering teams to operationalize models.Monitor model performance over time and recommend enhancements     as required.Contribute to agile project workstreams and participate in     ceremonies such as stand‑ups, reviews, and retrospectives.Required Skills & Competencies\n\nAnalytical & Technical Skills\n\nAbility to convert business challenges into analyt ...
# {'title': 'GoTo Financial - Senior Data Scientist', 'company_name': 'Confidential', 'location': 'Singapore', 'via': 'BeBee', 'share_link': 'https://www.google.com.sg/search?ibp=htl;jobs&q=data+scientist&htidocid=iGpvhWCDmBfOhWKEAAAAAA%3D%3D&hl=en-SG&shem=rimspwouoe&shndl=37&shmd=H4sIAAAAAAAA_xXNMQ7CMAxAUbH2BjB5RqJBSCwwMIDoAcpeuSGkRsGOYg8duQMT1-MktMvfvl71XVSnRm4CV2JkT5hgA21gkgIXNITWU2AjNfi9P_CUHjRg8QMIQyMSU1gdB7OsB-dUUx3V0MjXXl5OOPQyumnSOZ0OWEJOaKHb7bdjnTmul2fhB91nY7KJoSWOmKWEP6pjYbmcAAAA&shmds=v1_ATWGeePz0u3Aqoe67YnDqB0icGiutQljDgJ8eGvkz7pXKJ0-xQ&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=iGpvhWCDmBfOhWKEAAAAAA%3D%3D', 'extensions': ['3 days ago', 'Full–time'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}, 'source_link': 'https://bebee.com/sg/jobs/goto-financial-senior-data-scientist-confidential-singapore--clickajo-045d21ba0d80d0a64da5910241b30f80', 'job_title': 'GoTo Financial - Senior Data Scientist', 'description': "FinTech - Data Products & Infra • Singapore  About the Role  As a Data Scientist specializing in deep learning at GoTo, you will tackle complex challenges in computer vision, voice, and text processing. You will lead the development and deployment of advanced AI models that directly impact our key business products. Your responsibilities will include enhancing our systems with cutting‑edge deep learning models and ensuring they are scalable in a production environment. This role offers the opportunity to drive innovation, solve critical business challenges, and shape the future of AI‑driven financial solutions at GoTo.\nAbout the Team  At GoTo, our Data Science team is at the forefront of developing cutting‑edge deep learning solutions. We build advanced computer vision models for our KYC system, which is the leading KYC solution in Indonesia and is now expanding to external customers. We also create sophisticated deep‑learning models for computer vision, voice and text processing. Our team is composed of members with diverse backgrounds, bringing expertise in mathematics, statistics, machine learning, and deep learning. We tackle some of the most challenging business problems at GoPay and are passionate about both the technical aspects of data science and the tangible impact our models have on the business.\nWhat You Will Do   Work with data like images, videos, audio, and text etc.  Design, train, optimize, and deploy deep learning models with GPU.  Develop comprehensive unit tests and documentation, and rigorously evaluate and benchmark model performance and quality.  Communicate effectively between the business team and the engineering team to gather and implement project requirements.  Own the end‑to‑end process, from defining the technical problem to deploying the solution in collaboration with engineers.  Stay current with the latest advancements in deep learning and AI technologies.   What You Will Need   5+ years of experience in deep learning, particularly with computer vision, voice, and text processing.  Proficient in data preprocessing, model training, evaluation, and optimisation.  Practical experience in applying deep learning to solve real business problems, with models successfully deployed and used in production environments.  Proficient with deep learning frameworks such as PyTorch, and familiar with Python, C++, and inference engines like NCNN.   Experience with cloud platforms like GCP or AWS, and working knowledge of Android/iOS is a plus.  Strong communication skills to understand business needs and effectively convey analytical solutions.  Ability to write clear and concise technical documentation.  A Master’s or PhD in Computer Science, Data Science, AI, or a related field.   About GoTo Group  GoTo is the largest digital ecosystem in Indonesia. GoTo's mission is to 'empower progress' by offering technology infrastructure and solutions that help everyone to access and thrive in the digital economy.\nThe GoTo ecosy ...

# %%
jobs[0].keys()
# Out:
# dict_keys(['title', 'company_name', 'location', 'via', 'share_link', 'thumbnail', 'extensions', 'detected_extensions', 'source_link', 'job_title', 'description', 'apply_options', 'job_id'])

# %% [markdown]
# Salary detail is in the `extentions` key of the dictionaries.

# %%
for job in jobs:
    print(job['extensions'])
# Out:
# ['6 hours ago', 'Contractor']
# ['1 day ago', 'Full–time']
# ['2 days ago', 'Full–time and Contractor']
# ['1 day ago', 'Full–time']
# ['4 days ago', '$7K–$12K a month', 'Full–time']
# ['3 days ago', 'Full–time']
# ['3 days ago', 'Full–time']
# ['1 day ago', 'Full–time']
# ['4 days ago', '$6K–$10K a month', 'Full–time']
# ['3 days ago', 'Full–time']

# %%
for job in jobs:
    print(job['detected_extensions'])
# Out:
# {'posted_at': '6 hours ago', 'schedule_type': 'Contractor'}
# {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time and Contractor'}
# {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}
# {'posted_at': '4 days ago', 'salary': '$7K–$12K a month', 'schedule_type': 'Full–time'}
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
# {'posted_at': '1 day ago', 'schedule_type': 'Full–time'}
# {'posted_at': '4 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}

# %%
jobs_with_salary = []
for job in jobs:
    job_with_extensions = job.get('detected_extensions', [])
    if 'salary' in job_with_extensions.keys():
        jobs_with_salary.append({
            'title': job['title'],
            'company_name': job['company_name'],
            'job_title': job['job_title'],
            'description': job['description'],
            'salary': job_with_extensions['salary'],
        })

jobs_with_salary
# Out:
# [{'title': 'Data Scientist (GEN AI with AWS Bedrock)',
#   'company_name': 'INCOME INSURANCE LIMITED',
#   'job_title': 'Data Scientist (GEN AI with AWS Bedrock)',
#   'description': 'Analytics Center of Excellence (COE) at Income Insurance is the enterprise team that champions and develops AI/ML solutions. We focus on in-house solution development as well as partnerships. To ensure the successful execution of Income’s enterprise strategy to build Analytics as a product through impactful AI/ML solutions, driving innovation, and cultivating AI culture, we are seeking a highly skilled and experienced Data Scientist to join our team. The selected candidate will focus on building Generative AI-based solutions\n\n\nResponsibilities:\n\nTake ownership of AI/ML use cases, from design and implementation to continuous enhancement.Act as a technical specialist in AI, primarily focusing on Generative AI. Design and develop solutions to address various business challenges, particularly those related to optimizing operational efficiency.Collaborate with other data engineers, analysts, data scientists, product specialists, and stakeholders to build well-crafted, pragmatic, and robust solutions that meet business requirements.Stakeholder management and engagement: proactively engage with stakeholders to understand their needs and translate them into technical requirements for AI/ML modeling.Maintain documentation of dataset curation, modeling approach, model performance, code changes, and workflows.Demonstrate a strong understanding of data privacy regulations such as PDPA, and AI governance guidelines to ensure compliance.Foster an innovative and growth-oriented mindset, continuously seeking opportunities to enhance AI/ML models and drive improvements across the organization.Requirements:\n\n3–5 years of experience in a data science role, with demonstrable expertise in the AWS platform. Experience with Microsoft Copilot Studio is a plus.Bachelor’s degree in computer science or equivalent.Familiarity with techniques for Document Chunking, Embedding, and Information Retrieval for improving model accuracy and relevance.Expertise in Prompt Engineering for designing and managing effective prompts.Hands-on experience with AWS Bedrock, including deploying solutions using foundation models and integrating them into scalable applications using APIs and orchestration tools.Experience in Agentic Workflow for maximizing the utility of models, including understanding user intent and context to drive meaningful interactions.In-depth knowledge of supervised and unsupervised ML models – linear & logistic regression, clustering, tree-based models like random forest, bagging, and boosting models.Proficient in SQL, Python, and Spark.Proven experience in implementing MLOps practices on AWS.Familiar with Data Warehouses such as Redshift, Hive, and S3.Passionate about technology and always looking to upskill based on new developments in the AI space.AWS or Microsoft certifications will be a plus.Experience in the financial industry, telecommunications, or consulting is preferred',
#   'salary': '$7K–$12K a month'},
#  {'title': 'Assistant Data Scientists',
#   'company_name': 'OAKTREE CONSULTING',
#   'job_title': 'Assistant Data Scientists',
#   'description': 'The Data Scientist works closely with business stakeholders to uncover challenges, refine use cases, and design analytical solutions that drive measurable outcomes. This role spans the entire data science lifecycle—problem framing, data preparation, modelling, evaluation, communication of insights, and enabling adoption through compellingvisualizations and decision‑support tools.\n\nKey Responsibilities\n\n1. Problem Definition & StakeholderEngagement\n\nFacilitate discussions with business users to understand their     pain points, clarify objectives, and convert them into analytically sound     data science problem statements.Collaborate with stakeholders throughout the project to refine     hypotheses, validate findings, and align on priorities.Manage expectations and timelines while balancing analytical     depth with business needs.2. Data Preparation & FeatureEngineering\n\nConduct data cleaning, preprocessing, and transformation for     both structured and unstructured data to ensure high data quality.Perform feature engineering to extract meaningful attributes     that enhance model performance.Identify relevant datasets and integrate multiple data sources     to support analytical work.3. Analytical Modelling &Experimentation\n\nExplore data using statistical techniques to uncover trends,     patterns, and relationships.Build machine learning models for prediction, classification,     clustering, or other analytical tasks as required by the use case.Evaluate model performance and iterate based on stakeholder feedback     and performance metrics.4. Insights Delivery & Communication\n\nTranslate analytical results into actionable recommendations     that stakeholders can apply to drive decisions or business improvements.Develop clear, compelling narratives that explain insights and     model behaviours in an accessible manner.Present analysis with well‑designed visuals, dashboards, and     interactive tools that support storytelling and data exploration.5. Visualisation & User‑Facing Tools\n\nDesign dashboards and interactive visualizations to facilitate     self‑service analytics and real‑time data monitoring.Apply strong visualization principles to ensure insights are     intuitive and impactful.Build and deploy customised visual interfaces tightly     integrated with underlying data systems.6. Deployment, Monitoring &Continuous Improvement\n\nSupport model deployment into production environments and     collaborate with engineering teams to operationalize models.Monitor model performance over time and recommend enhancements     as required.Contribute to agile project workstreams and participate in     ceremonies such as stand‑ups, reviews, and retrospectives.Required Skills & Competencies\n\nAnalytical & Technical Skills\n\nAbility to convert business challenges into analytical     questions and identify appropriate data sources.Proficiency in writing data preparation and analysis scripts     using tools such as Python, R, SQL, pandas, or equivalent.Strong foundation in descriptive statistics, probability, data     exploration, and hypothesis testing.Skilled in building and validating machine learning models,     using modern techniques and frameworks.Solid understanding of system design concepts, data structures,     and algorithms.Data Visualization & Storytelling\n\nStrong command of data visualization principles and tools.Capable of developing dashboards and interactive visual tools     (e.g., using Tableau, Power BI, Plotly, or custom frameworks).Ability to communicate analytical insights through structured     storytelling tailored for decision‑makers.Data Engineering Familiarity\n\nUnderstanding of data modelling, data access patterns, and data     storage structures such as data lakes, data marts, and data warehouses.Familiarity with REST APIs, web protocols, and data extraction     via web scraping technologies.Comfortable working with big data frameworks (e.g., Spark,     Hadoop, Kafka) wh ...
#   'salary': '$6K–$10K a month'}]

# %%
pd.DataFrame(jobs_with_salary)
# Out:
#                                       title              company_name  \
# 0  Data Scientist (GEN AI with AWS Bedrock)  INCOME INSURANCE LIMITED
# 1                 Assistant Data Scientists        OAKTREE CONSULTING
#
#                                   job_title  \
# 0  Data Scientist (GEN AI with AWS Bedrock)
# 1                 Assistant Data Scientists
#
#                                          description            salary
# 0  Analytics Center of Excellence (COE) at Income...  $7K–$12K a month
# 1  The Data Scientist works closely with business...  $6K–$10K a month

# %% [markdown]
# # Scrape Multiple Pages

# %%
results = client.search({
    'engine': 'google_jobs',
    'q': 'data scientist',
    'location': 'Singapore',
    'google_domain': 'google.com.sg',
    'hl': 'en',
    'gl': 'sg',
})

jobs = results['jobs_results']
if len(jobs) == 0:
    print('No more jobs found.')

for job in jobs:
    job_with_extensions = job.get('detected_extensions', [])
    if 'salary' in job_with_extensions.keys():
        print(job)

# %%
pd.DataFrame(jobs)
# Out:
#                                                title  \
# 0  Senior Data Scientist, Generative AI & Health ...
# 1  Data Scientist Internship: Digital Tax Analyti...
# 2  Global Manufacturing Scheduling & AI Data Scie...
# 3    Data Scientist I — AI-Driven Analytics & Growth
# 4  Data Scientist, Real-Time Fulfilment & Driver ...
# 5       Data Scientist, Responsible AI (AI Practice)
# 6    Staff/Lead LLM Data Scientist (Singapore based)
# 7                             Data Scientist Analyst
# 8  Information Technology - Data Scientist (Data ...
# 9  Senior Data Scientist — Predictive & Generativ...
#
#                    company_name   location                 via  \
# 0                  Confidential  Singapore               BeBee
# 1                  Confidential  Singapore               BeBee
# 2                  Confidential  Singapore               BeBee
# 3                  Confidential  Singapore               BeBee
# 4                  Confidential  Singapore               BeBee
# 5  Government Technology Agency  Singapore         Careers@Gov
# 6                     Agoda.com  Singapore       Agoda Careers
# 7                  Confidential  Singapore               BeBee
# 8        Singapore Airlines Ltd        NaN  Singapore Airlines
# 9                  Confidential  Singapore               BeBee
#
#                                           share_link  \
# 0  https://www.google.com.sg/search?ibp=htl;jobs&...
# 1  https://www.google.com.sg/search?ibp=htl;jobs&...
# 2  https://www.google.com.sg/search?ibp=htl;jobs&...
# 3  https://www.google.com.sg/search?ibp=htl;jobs&...
# 4  https://www.google.com.sg/search?ibp=htl;jobs&...
# 5  https://www.google.com.sg/search?ibp=htl;jobs&...
# 6  https://www.google.com.sg/search?ibp=htl;jobs&...
# 7  https://www.google.com.sg/search?ibp=htl;jobs&...
# 8  https://www.google.com.sg/search?ibp=htl;jobs&...
# 9  https://www.google.com.sg/search?ibp=htl;jobs&...
#
#                  extensions  \
# 0    [1 day ago, Full–time]
# 1   [1 day ago, Internship]
# 2    [1 day ago, Full–time]
# 3   [3 days ago, Full–time]
# 4   [3 days ago, Full–time]
# 5  [12 days ago, Full–time]
# 6               [Full–time]
# 7    [1 day ago, Full–time]
# 8  [13 days ago, Full–time]
# 9    [1 day ago, Full–time]
#
#                                  detected_extensions  \
# 0  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 1  {'posted_at': '1 day ago', 'schedule_type': 'I...
# 2  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 3  {'posted_at': '3 days ago', 'schedule_type': '...
# 4  {'posted_at': '3 days ago', 'schedule_type': '...
# 5  {'posted_at': '12 days ago', 'schedule_type': ...
# 6                     {'schedule_type': 'Full–time'}
# 7  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 8  {'posted_at': '13 days ago', 'schedule_type': ...
# 9  {'posted_at': '1 day ago', 'schedule_type': 'F...
#
#                                          source_link  \
# 0  https://bebee.com/sg/jobs/senior-data-scientis...
# 1  https://bebee.com/sg/jobs/data-scientist-inter...
# 2  https://bebee.com/sg/jobs/global-manufacturing...
# 3  https://bebee.com/sg/jobs/data-scientist-i-ai-...
# 4  https://bebee.com/sg/jobs/data-scientist-real-...
# 5  https://jobs.careers.gov.sg/jobs/hrp/15079033/...
# 6  https://careersatagoda.com/job/5393397-staff-l...
# 7  https://bebee.com/sg/jobs/data-scientist-analy...
# 8  https://careers.singaporeair.com/sia/job/Infor...
# 9  https://bebee.com/sg/jobs/senior-data-scientis...
#
#                                            job_title  \
# 0  Senior Data Scientist, Generative AI & Health ...
# 1  Data Scientist Internship: Digital Tax Analyti...
# 2  Global Manufacturing Scheduling & AI Data Scie...
# 3    Data Scientist I — AI-Driven Analytics & Growth
# 4  Data Scientist, Real-Time Fulfilment & Driver ...
# 5       Data Scientist, Responsible AI (AI Practice)
# 6    Staff/Lead LLM Data Scientist (Singapore based)
# 7                             Data Scientist Analyst
# 8  Information Technology - Data Scientist (Data ...
# 9  Senior Data Scientist — Predictive & Generativ...
#
#                                          description  \
# 0  A leading insurance firm in Singapore is seeki...
# 1  A leading professional services firm in Singap...
# 2  A leading semiconductor company located in Sin...
# 3  A global data solutions provider in Singapore ...
# 4  A leading multi-service platform in Singapore ...
# 5  What the role is:\n\nThe Government Technology...
# 6  About Agoda\n\n\nAt Agoda, we bridge the world...
# 7  Responsibilities Collaborate with cross-functi...
# 8  Job Description SIA has multiple positions for...
# 9  A leading global communications group in Singa...
#
#                                        apply_options  \
# 0  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 1  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 2  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 3  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 4  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 5  [{'title': 'Careers@Gov', 'link': 'https://job...
# 6  [{'title': 'Agoda Careers', 'link': 'https://c...
# 7  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 8  [{'title': 'Singapore Airlines', 'link': 'http...
# 9  [{'title': 'BeBee', 'link': 'https://bebee.com...
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBTY2llbnRpc3...
# 1  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCBJbnRlcm...
# 2  eyJqb2JfdGl0bGUiOiJHbG9iYWwgTWFudWZhY3R1cmluZy...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCBJIOKAlC...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCwgUmVhbC...
# 5  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCwgUmVzcG...
# 6  eyJqb2JfdGl0bGUiOiJTdGFmZi9MZWFkIExMTSBEYXRhIF...
# 7  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCBBbmFseX...
# 8  eyJqb2JfdGl0bGUiOiJJbmZvcm1hdGlvbiBUZWNobm9sb2...
# 9  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBTY2llbnRpc3...
#
#                                            thumbnail
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  https://serpapi.com/searches/69e57938cf8870575...
# 6  https://serpapi.com/searches/69e57938cf8870575...
# 7                                                NaN
# 8  https://serpapi.com/searches/69e57938cf8870575...
# 9                                                NaN

# %% [markdown]
# SerpAPI pagination has `next_page_token` which can be used to load data from the next page.

# %%
results['serpapi_pagination']
# Out:
# {'next_page_token': '...',
#  'next': 'https://serpapi.com/search.json?engine=google_jobs&gl=sg&google_domain=google.com.sg&hl=en&location=Singapore&next_page_token=...&q=data+scientist'}

# %%
results['serpapi_pagination']['next_page_token']
# Out:
# '...'

# %% [markdown]
# Sample job data from the next page:

# %%
results = client.search({
    'engine': 'google_jobs',
    'q': 'data scientist',
    'location': 'Singapore',
    'google_domain': 'google.com.sg',
    'hl': 'en',
    'gl': 'sg',
    'next_page_token': results['serpapi_pagination']['next_page_token']
})

jobs = results['jobs_results']
if len(jobs) == 0:
    print('No more jobs found.')

for job in jobs:
    job_with_extensions = job.get('extensions', [])
    for component in job_with_extensions:
        if '$' in component:
            print(job)

# %%
pd.DataFrame(jobs)
# Out:
#                                                title  \
# 0  Junior Data Scientist - AI-Driven Growth & Ins...
# 1    Data Scientist/ Senior Data Scientist, Singpass
# 2  Data Scientist, Jobs-Skills Intelligence & Ana...
# 3  Information Technology - Senior Data Scientist...
# 4   AI-Driven Data Scientist: Build Scalable ML APIs
# 5   Healthcare Data Scientist: Turn Data into Action
# 6    Data Scientist, SMART Manufacturing – Singapore
# 7  Data Scientist – Media & Music Insights (Singa...
# 8  Senior Data Scientist, Product Analytics & Exp...
# 9                    Data Scientist Analyst (Python)
#
#                    company_name   location                 via  \
# 0                  Confidential  Singapore               BeBee
# 1  Government Technology Agency  Singapore         Careers@Gov
# 2                  Confidential  Singapore               BeBee
# 3        Singapore Airlines Ltd        NaN  Singapore Airlines
# 4                  Confidential  Singapore               BeBee
# 5                  Confidential  Singapore               BeBee
# 6                  Confidential  Singapore               BeBee
# 7                  Confidential  Singapore               BeBee
# 8                  Confidential  Singapore               BeBee
# 9                       Exasoft  Singapore  LinkedIn Singapore
#
#                                           share_link  \
# 0  https://www.google.com.sg/search?ibp=htl;jobs&...
# 1  https://www.google.com.sg/search?ibp=htl;jobs&...
# 2  https://www.google.com.sg/search?ibp=htl;jobs&...
# 3  https://www.google.com.sg/search?ibp=htl;jobs&...
# 4  https://www.google.com.sg/search?ibp=htl;jobs&...
# 5  https://www.google.com.sg/search?ibp=htl;jobs&...
# 6  https://www.google.com.sg/search?ibp=htl;jobs&...
# 7  https://www.google.com.sg/search?ibp=htl;jobs&...
# 8  https://www.google.com.sg/search?ibp=htl;jobs&...
# 9  https://www.google.com.sg/search?ibp=htl;jobs&...
#
#                  extensions  \
# 0   [3 days ago, Full–time]
# 1   [5 days ago, Full–time]
# 2   [3 days ago, Full–time]
# 3  [10 days ago, Full–time]
# 4  [3 days ago, Internship]
# 5    [1 day ago, Full–time]
# 6   [3 days ago, Full–time]
# 7   [3 days ago, Full–time]
# 8   [3 days ago, Full–time]
# 9  [3 days ago, Contractor]
#
#                                  detected_extensions  \
# 0  {'posted_at': '3 days ago', 'schedule_type': '...
# 1  {'posted_at': '5 days ago', 'schedule_type': '...
# 2  {'posted_at': '3 days ago', 'schedule_type': '...
# 3  {'posted_at': '10 days ago', 'schedule_type': ...
# 4  {'posted_at': '3 days ago', 'schedule_type': '...
# 5  {'posted_at': '1 day ago', 'schedule_type': 'F...
# 6  {'posted_at': '3 days ago', 'schedule_type': '...
# 7  {'posted_at': '3 days ago', 'schedule_type': '...
# 8  {'posted_at': '3 days ago', 'schedule_type': '...
# 9  {'posted_at': '3 days ago', 'schedule_type': '...
#
#                                          source_link  \
# 0  https://bebee.com/sg/jobs/junior-data-scientis...
# 1  https://jobs.careers.gov.sg/jobs/hrp/16363684/...
# 2  https://bebee.com/sg/jobs/data-scientist-jobs-...
# 3  https://careers.singaporeair.com/sia/job/Infor...
# 4  https://bebee.com/sg/jobs/ai-driven-data-scien...
# 5  https://bebee.com/sg/jobs/healthcare-data-scie...
# 6  https://bebee.com/sg/jobs/data-scientist-smart...
# 7  https://bebee.com/sg/jobs/data-scientist-media...
# 8  https://bebee.com/sg/jobs/senior-data-scientis...
# 9  https://sg.linkedin.com/jobs/view/data-scienti...
#
#                                            job_title  \
# 0  Junior Data Scientist - AI-Driven Growth & Ins...
# 1    Data Scientist/ Senior Data Scientist, Singpass
# 2  Data Scientist, Jobs-Skills Intelligence & Ana...
# 3  Information Technology - Senior Data Scientist...
# 4   AI-Driven Data Scientist: Build Scalable ML APIs
# 5   Healthcare Data Scientist: Turn Data into Action
# 6    Data Scientist, SMART Manufacturing – Singapore
# 7  Data Scientist – Media & Music Insights (Singa...
# 8  Senior Data Scientist, Product Analytics & Exp...
# 9                    Data Scientist Analyst (Python)
#
#                                          description  \
# 0  A global technology company is looking for a D...
# 1  What the role is:\n\nGovTech is the lead agenc...
# 2  A government agency in Singapore is seeking a ...
# 3  Job Description This is a senior data scientis...
# 4  An international airline is seeking junior and...
# 5  A leading tech firm in Singapore is seeking a ...
# 6  A major player in the manufacturing industry i...
# 7  A Big Tech company in Singapore is seeking a D...
# 8  A leading transportation technology company ba...
# 9  Responsibilities\n\n\n\n\n•Collaborate with cr...
#
#                                        apply_options  \
# 0  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 1  [{'title': 'Careers@Gov', 'link': 'https://job...
# 2  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 3  [{'title': 'Singapore Airlines', 'link': 'http...
# 4  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 5  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 6  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 7  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 8  [{'title': 'BeBee', 'link': 'https://bebee.com...
# 9  [{'title': 'LinkedIn Singapore', 'link': 'http...
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJKdW5pb3IgRGF0YSBTY2llbnRpc3...
# 1  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdC8gU2VuaW...
# 2  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCwgSm9icy...
# 3  eyJqb2JfdGl0bGUiOiJJbmZvcm1hdGlvbiBUZWNobm9sb2...
# 4  eyJqb2JfdGl0bGUiOiJBSS1Ecml2ZW4gRGF0YSBTY2llbn...
# 5  eyJqb2JfdGl0bGUiOiJIZWFsdGhjYXJlIERhdGEgU2NpZW...
# 6  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCwgU01BUl...
# 7  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCDigJMgTW...
# 8  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBTY2llbnRpc3...
# 9  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCBBbmFseX...
#
#                                            thumbnail
# 0                                                NaN
# 1  https://serpapi.com/searches/69e589b1556ce3818...
# 2                                                NaN
# 3  https://serpapi.com/searches/69e589b1556ce3818...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  https://serpapi.com/searches/69e589b1556ce3818...

# %%
jobs_with_salary = []
for job in jobs:
    job_with_extensions = job.get('detected_extensions', [])
    if 'salary' in job_with_extensions.keys():
        jobs_with_salary.append({
            'title': job['title'],
            'company_name': job['company_name'],
            'job_title': job['job_title'],
            'description': job['description'],
            'salary': job_with_extensions['salary'],
        })

jobs_with_salary
# Out:
# []

# %% [markdown]
# Load job data from multiple pages:

# %%
page_number = 0
while True:
    search_params = {
        'engine': 'google_jobs',
        'q': 'data scientist',
        'location': 'Singapore',
        'google_domain': 'google.com.sg',
        'hl': 'en',
        'gl': 'sg',
    }

    results = client.search(search_params)
    jobs = results['jobs_results']
    print(f'\nFound {len(jobs)} jobs on page {page_number + 1}.')
    print(jobs)
    if len(jobs) == 0:
        print('No more jobs found.')

    jobs_with_salary = []
    for job in jobs:
        detected_extensions = job.get('detected_extensions', {})
        print('\nDetected extensions for this job')
        print(detected_extensions)
        if 'salary' in detected_extensions.keys():
            jobs_with_salary.append({
                'title': job['title'],
                'company_name': job['company_name'],
                'job_title': job['job_title'],
                'description': job['description'],
                'salary': detected_extensions['salary'],
            })

    next_page_token = results['serpapi_pagination']['next_page_token']
    if next_page_token:
        search_params['next_page_token'] = next_page_token
    if page_number >= 5: # Limit page number to 5 to save credits
        break
    page_number += 1
# Out:
# Found 10 jobs on page 1.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}
#
# Found 10 jobs on page 2.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}
#
# Found 10 jobs on page 3.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}
#
# Found 10 jobs on page 4.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}
#
# Found 10 jobs on page 5.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}
#
# Found 10 jobs on page 6.
# [{'title': 'Data Scientist (AI Engineer)', 'company_name': 'ONE TECH STOP PTE. LTD.', 'location': 'Singapore', 'via': 'MyCareersFuture', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D&hl=en-SG&shndl=37&shmd=H4sIAAAAAAAA_xXLMQrCMBQAUFx7BKc_OKhDIkIXncQGFcQWmr2k4ZNGahLy_9DRO7h5PE-iLm97xXtWlJVhA631GNgTw_JwARWcD4h5BZ_nC-6xB0KT7QAxwClGN-J8PzAn2klJNApHbNhbYeNDxoB9nOQv0Z-OBpMxjYax25abSaTg1ov6pkCr4xlaXTfQaCXgqisBPkDrgzMpZvwCIk0w3Z0AAAA&shmds=v1_ATWGeeMG_0eDvLHlaOh78AXqmHcaF1PsSAgWfFmQsgaH9268iA&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+scientist&htidocid=FsBuKyZWj9eUI71FAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/69e9ca901dcfe2113345b9ed/images/G7l0kInIAisE2vGpxl9jianG9A6_hYegc7ej187fZGU.jpeg', 'extensions': ['2 days ago', '$5K–$7K a month', 'Full–time and Contractor'], 'detected_extensions': {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}, 'source_link': 'https://www.mycareersfuture.gov.sg/job/information-technology/data-scientist-one-tech-stop-064510c740230e40b8d3e3cce31cc60f', 'job_title': 'Data Scientist (AI Engineer)', 'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms fo ...
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$5K–$7K a month', 'schedule_type': 'Full–time and Contractor'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'salary': '$6K–$10K a month', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '3 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'posted_at': '2 days ago', 'schedule_type': 'Full–time'}
#
# Detected extensions for this job
# {'schedule_type': 'Full–time'}

# %%
jobs_with_salary
# Out:
# [{'title': 'Data Scientist (AI Engineer)',
#   'company_name': 'ONE TECH STOP PTE. LTD.',
#   'job_title': 'Data Scientist (AI Engineer)',
#   'description': 'JOB OVERVIEW:\n\nThe Data Scientist (AI Engineer) serves as the critical technical bridge between high-level business strategy and scalable AI production. This role is dedicated to accelerating demand creation by translating complex client challenges into feasible, high-impact AI/ML prototypes and Proof of Concepts (PoCs).\n\nBy balancing technical rigor with strategic communication, the incumbent assesses data maturity, designs agile solutions using both traditional and Generative AI, and ensures that all innovations are architecturally sound and ready for production handover. Ultimately, this role drives organizational growth by de-risking AI investments and demonstrating the tangible technical value of emerging technologies.\n\n\nCore Focus Areas\n\nTechnical Translation: Converting business "pain points" into rigorous technical requirements and feasible AI architectures.\n\nRapid Innovation: Designing and iterating on interactive prototypes that showcase the "art of the possible" while adhering to vetted Technology Readiness Level (TRL) standards.\n\nStrategic Advisory: Evaluating client data infrastructure and providing technical roadmaps to bridge the gap between current capabilities and AI readiness.\n\nSeamless Integration: Partnering with Production and Enablement leads to ensure prototypes are scalable, documented, and transitioned without technical debt.\n\nTechnology Scouting: Researching and applying cutting-edge tools from the internal Tech Radar to solve real-world client problems.\n\n\n\nDUTIES AND RESPONSIBILITIES:\n\nTechnical Requirements Elicitation & Analysis:\n\nCollaborate with AI/ML Business Analysts and clients to deeply understand their existing technical landscape, data infrastructure, and specific operational challenges.\n\nTranslate high-level business needs into technical requirements for AI/ML solutions, identifying necessary data inputs, system integrations, and potential technical constraints.\n\nAssess the technical feasibility of proposed AI/ML use cases, ensuring alignment with the organization’s vetted tech stack and TRL standards, given the client\'s current data capabilities and technology stack.\n\nAI/ML Solution Conceptualization & Prototyping:\n\nDesign and develop rapid, interactive prototypes or proof-of-concepts (PoCs) using appropriate AI/ML techniques (both traditional ML and cutting-edge AI like Generative AI).\n\nDemonstrate the functionality and potential business impact of AI/ML solutions through compelling technical demonstrations and visualizations.\n\nIterate rapidly on prototypes based on client feedback, showcasing agility and responsiveness.\n\nTechnical Communication & Value Articulation:\n\nSimplify complex AI/ML concepts, algorithms, and technical architectures into understandable terms for non-technical business stakeholders.\n\nClearly articulate the technical value proposition of proposed solutions, explaining how the AI/ML will work and why it is the right approach for the client\'s problem.\n\nPresent technical findings, prototype results, and architectural considerations to clients and internal teams.\n\nOrganizational Data Capability Assessment (Technical):\n\nConduct technical assessments of client data maturity, including data quality, accessibility, governance, and existing infrastructure.\n\nAdvise clients on technical prerequisites and potential roadmaps for enhancing their data capabilities to support AI/ML initiatives.\n\nEmerging Technology Research & Application:\n\nActively research and evaluate new AI/ML technologies, tools, and frameworks (e.g., specific algorithms, cloud AI services, MLOps tools) relevant to demand creation and prototyping.\n\nSupport the AI Solution Enablement Lead by exploring specific application-layer use cases for technologies already on the internal Tech Radar. Provide field feedback on the performance of vetted tools in client prototypes\n\nIdentify how emerging technical capabilities can be applied to solv ...
#   'salary': '$5K–$7K a month'},
#  {'title': 'Assistant Data Scientists',
#   'company_name': 'OAKTREE CONSULTING',
#   'job_title': 'Assistant Data Scientists',
#   'description': 'The Data Scientist works closely with business stakeholders to uncover challenges, refine use cases, and design analytical solutions that drive measurable outcomes. This role spans the entire data science lifecycle—problem framing, data preparation, modelling, evaluation, communication of insights, and enabling adoption through compellingvisualizations and decision‑support tools.\n\nKey Responsibilities\n\n1. Problem Definition & StakeholderEngagement\n\nFacilitate discussions with business users to understand their     pain points, clarify objectives, and convert them into analytically sound     data science problem statements.Collaborate with stakeholders throughout the project to refine     hypotheses, validate findings, and align on priorities.Manage expectations and timelines while balancing analytical     depth with business needs.2. Data Preparation & FeatureEngineering\n\nConduct data cleaning, preprocessing, and transformation for     both structured and unstructured data to ensure high data quality.Perform feature engineering to extract meaningful attributes     that enhance model performance.Identify relevant datasets and integrate multiple data sources     to support analytical work.3. Analytical Modelling &Experimentation\n\nExplore data using statistical techniques to uncover trends,     patterns, and relationships.Build machine learning models for prediction, classification,     clustering, or other analytical tasks as required by the use case.Evaluate model performance and iterate based on stakeholder feedback     and performance metrics.4. Insights Delivery & Communication\n\nTranslate analytical results into actionable recommendations     that stakeholders can apply to drive decisions or business improvements.Develop clear, compelling narratives that explain insights and     model behaviours in an accessible manner.Present analysis with well‑designed visuals, dashboards, and     interactive tools that support storytelling and data exploration.5. Visualisation & User‑Facing Tools\n\nDesign dashboards and interactive visualizations to facilitate     self‑service analytics and real‑time data monitoring.Apply strong visualization principles to ensure insights are     intuitive and impactful.Build and deploy customised visual interfaces tightly     integrated with underlying data systems.6. Deployment, Monitoring &Continuous Improvement\n\nSupport model deployment into production environments and     collaborate with engineering teams to operationalize models.Monitor model performance over time and recommend enhancements     as required.Contribute to agile project workstreams and participate in     ceremonies such as stand‑ups, reviews, and retrospectives.Required Skills & Competencies\n\nAnalytical & Technical Skills\n\nAbility to convert business challenges into analytical     questions and identify appropriate data sources.Proficiency in writing data preparation and analysis scripts     using tools such as Python, R, SQL, pandas, or equivalent.Strong foundation in descriptive statistics, probability, data     exploration, and hypothesis testing.Skilled in building and validating machine learning models,     using modern techniques and frameworks.Solid understanding of system design concepts, data structures,     and algorithms.Data Visualization & Storytelling\n\nStrong command of data visualization principles and tools.Capable of developing dashboards and interactive visual tools     (e.g., using Tableau, Power BI, Plotly, or custom frameworks).Ability to communicate analytical insights through structured     storytelling tailored for decision‑makers.Data Engineering Familiarity\n\nUnderstanding of data modelling, data access patterns, and data     storage structures such as data lakes, data marts, and data warehouses.Familiarity with REST APIs, web protocols, and data extraction     via web scraping technologies.Comfortable working with big data frameworks (e.g., Spark,     Hadoop, Kafka) wh ...
#   'salary': '$6K–$10K a month'}]

# %%
pd.DataFrame(jobs_with_salary)
# Out:
#                           title             company_name  \
# 0  Data Scientist (AI Engineer)  ONE TECH STOP PTE. LTD.
# 1     Assistant Data Scientists       OAKTREE CONSULTING
#
#                       job_title  \
# 0  Data Scientist (AI Engineer)
# 1     Assistant Data Scientists
#
#                                          description            salary
# 0  JOB OVERVIEW:\n\nThe Data Scientist (AI Engine...   $5K–$7K a month
# 1  The Data Scientist works closely with business...  $6K–$10K a month
